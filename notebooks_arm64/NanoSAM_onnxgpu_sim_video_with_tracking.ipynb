# %% [markdown]
# # Headless Video processing: Nvidia AI IOT NanoSAM
# ### .onnx (onnxruntime-gpu)
# July 29th

# %% [markdown]
# NanoSAM is a Segment Anything (SAM) model variant that is capable of running in 🔥 real-time 🔥 on NVIDIA Jetson Orin Platforms with NVIDIA TensorRT.

# %%
# ------------------------------------------------------------ #
#                 Clean environment setup
# ------------------------------------------------------------ #

"""
# clean env wipe & activate
conda env remove --name nanosam_arm64 -y
conda deactivate
conda create -n nanosam_arm64 python=3.10 -y
conda activate nanosam_arm64

sudo apt update
sudo apt install libcudnn8 libcudnn8-dev
conda install -c conda-forge libstdcxx-ng=12 -y

"""
# Out:
# '\n# clean env wipe & activate\nconda env remove --name nanosam_arm64 -y\nconda deactivate\nconda create -n nanosam_arm64 python=3.10 -y\nconda activate nanosam_arm64\n\nsudo apt update\nsudo apt install libcudnn8 libcudnn8-dev\nconda install -c conda-forge libstdcxx-ng=12 -y\n\n'

# %%
# ------------------------------------------------------------ #
#        Installation of nanosam_arm64 repo requirements
# ------------------------------------------------------------ #

"""
git clone https://github.com/NVIDIA-AI-IOT/nanosam
cd nanosam
python3 setup.py develop --user


# More requirements
pip install timm==1.0.17 ultralytics==8.0.120 matplotlib==3.5.3 'opencv-python<4.9' jetson-stats


# Typical np version mismatch
pip uninstall -y numpy
pip install "numpy>=1.19.2,<2.0"
# pip install numpy==1.26.4 

# Now install the CUDA PyTorch 2.5.0a0 (compatible with jp61 torch)
pip install --no-cache https://developer.download.nvidia.com/compute/redist/jp/v61/pytorch/torch-2.5.0a0+872d972e41.nv24.08.17622132-cp310-cp310-linux_aarch64.whl

# download torchvision 0.20.0a0 (compatible with jp61 torch)
cd ~/vision/
python3 setup.py install
cd ~

# --- ONNXRUNTIME-GPU (find appropriate aarch64 whl online) ------------- #

pip uninstall onnxruntime -y
pip install https://github.com/ultralytics/assets/releases/download/v0.0.0/onnxruntime_gpu-1.20.0-cp310-cp310-linux_aarch64.whl
pip install sympy==1.13.1 numpy==1.26.4

"""

# Debug Support

# Check your conda env GLIBCXX versions
# strings /home/copter/miniconda3/envs/nanosam_arm64/lib/python3.10/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6 | grep GLIBCXX

# trt2torch is apparently an issue and is obsolete for trt --version=10.3.0 
# additionally `pip install pycuda`
# Out:
# '\ngit clone https://github.com/NVIDIA-AI-IOT/nanosam\ncd nanosam\npython3 setup.py develop --user\n\n\n# More requirements\npip install timm==1.0.17 ultralytics==8.0.120 matplotlib==3.5.3 \'opencv-python<4.9\' jetson-stats\n\n\n# Typical np version mismatch\npip uninstall -y numpy\npip install "numpy>=1.19.2,<2.0"\n# pip install numpy==1.26.4 \n\n# Now install the CUDA PyTorch 2.5.0a0 (compatible with jp61 torch)\npip install --no-cache https://developer.download.nvidia.com/compute/redist/jp/v61/pytorch/torch-2.5.0a0+872d972e41.nv24.08.17622132-cp310-cp310-linux_aarch64.whl\n\n# download torchvision 0.20.0a0 (compatible with jp61 torch)\ncd ~/vision/\npython3 setup.py install\ncd ~\n\n# --- ONNXRUNTIME-GPU (find appropriate aarch64 whl online) ------------- #\n\npip uninstall onnxruntime -y\npip install https://github.com/ultralytics/assets/releases/download/v0.0.0/onnxruntime_gpu-1.20.0-cp310-cp310-linux_aarch64.whl\npip install sympy==1.13.1 numpy==1.26.4\n\n'

# %%
# from nanosam.utils.predictor import Predictor
import onnxruntime as ort

# %%
import onnx
import numpy as np
from PIL import Image, ImageDraw
import PIL 
import matplotlib.pyplot as plt
import cv2
import os
import torch
import tensorrt     # import even if not used
from typing import Tuple, Optional, List
import time
from enum import Enum
from torchvision import transforms
import logging

# ---- LOGGING CONF ----------------------- #

logger = logging.getLogger(__name__)

# For development/debugging
logging.basicConfig(level=logging.INFO)
# logging.basicConfig(level=logging.DEBUG)

# %%
# tracking imports
from nanosam.utils.predictor import Predictor
from nanosam.utils.tracker import Tracker
from nanosam.utils.predictor import ONNXPredictor
from nanosam.utils.tracker import ONNXTracker

# %%
# Verify versions

print(f"ONNX version: {onnx.__version__}")
print(f"NumPy version: {np.__version__}")       # shold be 1.26.4 or else causes mem core dump issues
print(f"TensorRT version: {tensorrt.__version__}")
print("Available ONNX Runtime providers: ", ort.get_available_providers())
# Out:
# ONNX version: 1.13.1
# NumPy version: 1.26.4
# TensorRT version: 10.3.0
# Available ONNX Runtime providers:  ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']

# %%
# 🧹 Clear the PyTorch CUDA cache
torch.cuda.empty_cache()

import gc
gc.collect()

# Prevent TensorRT plugin conflicts
os.environ['ORT_DISABLE_TRT_PLUGINS'] = '1'

# %%
# --- Resource allocation --------------
def check_gpu_memory():
    """Check GPU memory usage"""
    if torch.cuda.is_available():
        for i in range(torch.cuda.device_count()):
            memory_allocated = torch.cuda.memory_allocated(i) / 1024**3  # GB
            memory_reserved = torch.cuda.memory_reserved(i) / 1024**3    # GB
            memory_total = torch.cuda.get_device_properties(i).total_memory / 1024**3
            print(f"GPU {i}: {memory_allocated:.2f}GB allocated, {memory_reserved:.2f}GB reserved, {memory_total:.2f}GB total")
    else:
        print("CUDA not available")

def check_cpu_memory():
    """Check CPU memory usage"""
    memory = psutil.virtual_memory()
    process = psutil.Process()
    process_memory = process.memory_info().rss / 1024**3  # GB
    
    print(f"System RAM: {memory.used/1024**3:.2f}GB used / {memory.total/1024**3:.2f}GB total ({memory.percent:.1f}%)")
    print(f"Current process: {process_memory:.2f}GB")

def check_onnx_provider_status(enc_sess=None, dec_sess=None):
    """Check available ONNX Runtime providers and their status"""

    if enc_sess and enc_sess != None:
        print("Available Encoder ONNX Runtime providers:", enc_sess.get_providers())
        print("Available Decoder ONNX Runtime providers:", dec_sess.get_providers())
    else:
        available = ort.get_available_providers()
        print("Available ONNX Runtime providers:", available)

    
    # Check if TensorRT is causing issues
    import os
    trt_disabled = os.environ.get('ORT_DISABLE_TRT_PLUGINS', 'Not Set')
    print(f"ORT_DISABLE_TRT_PLUGINS: {trt_disabled}")


# check_cpu_memory()
# check_onnx_provider_status(enc_sess, dec_sess)

# %% [markdown]
# ### Direct video processing

# %%
class PromptMode(Enum):
    POINT = "point"
    HEADING = "heading"
    BBOX = "bbox"
    EVERYTHING = "everything"
    TRACKING = "tracking"
    TRACKING_ALGO = "tracking_algo"

# %%
# Configuration Variables for the Notebook

ENCODER_MODEL="/home/copter/onnx_models/nvidia_ai_iot_resnet18_image_encoder.onnx"
DECODER_MODEL="/home/copter/onnx_models/nvidia_ai_iot_mobile_sam_mask_decoder.onnx"
INPUT_VIDEO = "/home/copter/Data/SimulatedDroneAngledCity - Trimmed 2.mp4"
OUTPUT_VIDEO = "/home/copter/Data/sim_tracker_algo_output_3.mp4"
GRID_SIZE = 8
SHOW_BBOX_OVERLAY = False
PROMPT_MODE = PromptMode.TRACKING_ALGO

# %%
class NanoSAMEnhanced:
    def __init__(self, 
                 encoder_path: str,
                 decoder_path: str,
                 device_id: int = 0,
                 input_size: Tuple[int, int] = (1024, 1024)):
        """
        Enhanced NanoSAM with multiple prompt types
        """
        self.device_id = device_id
        self.input_size = input_size
        
        # Initialize ONNX Runtime sessions with proper configuration for Jetson
        providers = ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
        
        # Configure session options to avoid thread affinity warnings on ARM64
        sess_options = ort.SessionOptions()
        sess_options.inter_op_num_threads = 1  # Reduce inter-op parallelism
        sess_options.intra_op_num_threads = 4  # Set explicit thread count
        sess_options.execution_mode = ort.ExecutionMode.ORT_SEQUENTIAL
        sess_options.graph_optimization_level = ort.GraphOptimizationLevel.ORT_ENABLE_ALL
        
        # Suppress verbose logging
        sess_options.log_severity_level = 3  # Only show errors
        
        try:
            logger.info("Loading encoder model...")
            self.encoder_session = ort.InferenceSession(
                encoder_path, 
                sess_options, 
                providers=providers
            )
            logger.info("Loading decoder model...")
            self.decoder_session = ort.InferenceSession(
                decoder_path, 
                sess_options, 
                providers=providers
            )
             
            logger.info(f"Using enc_sess providers: {self.encoder_session.get_providers()}")
            logger.info(f"Using dec_sess providers: {self.decoder_session.get_providers()}")
        except Exception as e:
            logger.info(f"❌ GPU session creation failed: {e}")
            logger.info("🔄 Falling back to CPU-only providers...")
            try:
                # Fallback to CPU only
                cpu_providers = ['CPUExecutionProvider']
                self.encoder_session = ort.InferenceSession(encoder_path, sess_options=sess_options, providers=cpu_providers)
                self.decoder_session = ort.InferenceSession(decoder_path, sess_options=sess_options, providers=cpu_providers)
                logger.info("✅ CPU fallback successful")
            except Exception as cpu_e:
                logger.info(f"❌ CPU fallback also failed: {cpu_e}")
                raise RuntimeError("Failed to load ONNX models with any provider")
        
        # Get input/output names
        self.encoder_input_name = self.encoder_session.get_inputs()[0].name
        self.encoder_output_name = self.encoder_session.get_outputs()[0].name
        
        self.decoder_input_names = [inp.name for inp in self.decoder_session.get_inputs()]
        self.decoder_output_name = self.decoder_session.get_outputs()[0].name
        
        logger.info(f"Decoder inputs: {self.decoder_input_names}")
        logger.info(f"Decoder outputs: {[out.name for out in self.decoder_session.get_outputs()]}")
        
        # Check if we have multiple outputs (masks, scores, logits)
        self.decoder_outputs = [out.name for out in self.decoder_session.get_outputs()]
        if len(self.decoder_outputs) > 1:
            logger.info(f"Multiple decoder outputs detected: {self.decoder_outputs}")
            # Look for mask-related output names
            mask_output_candidates = ['masks', 'low_res_masks', 'output_masks', 'segmentation_masks']
            for candidate in mask_output_candidates:
                if candidate in self.decoder_outputs:
                    self.decoder_output_name = candidate
                    logger.info(f"Using mask output: {candidate}")
                    break
        
        # Image preprocessing
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize(input_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                               std=[0.229, 0.224, 0.225])
        ])
        
        # Initialize camera
        self.cap = None
        
        # FPS tracking
        self.fps_counter = 0
        self.fps_start_time = time.time()
        self.current_fps = 0
        
        # Prompt state
        # self.current_mode = PromptMode.POINT
        self.current_mode = PromptMode.TRACKING_ALGO
        # self.current_mode = PromptMode.TRACKING
        # self.current_mode = PromptMode.HEADING
        # self.current_mode = PromptMode.EVERYTHING
        self.show_bbox = True                   # New toggle for bounding box visualization


        self.positive_points = []
        self.negative_points = []
        self.fixed_points = []
        self.bbox_start = None
        self.bbox_end = None
        self.drawing_bbox = False
        self.everything_mode_active = False

        
        # Everything mode grid settings
        self.grid_size = 8   # 32  # Grid points for everything mode
        
        # Tracker initialization
        try:
            # Create predictor with ONNX models (not TensorRT engines)
            self.predictor = ONNXPredictor(
                image_encoder_size=input_size[0],
                orig_image_encoder_size=input_size[0],
                encoder_session=self.encoder_session,    # Pass existing session
                decoder_session=self.decoder_session     # Pass existing session
            )
            self.tracker = ONNXTracker(self.predictor)
            logger.info("✅ Tracker initialized with ONNX models")
        except Exception as e:
            logger.info(f"❌ Failed to initialize tracker: {e}")
            self.tracker = None
    
        # Tracking state
        self.tracking_active = False
        self.tracked_mask = None
        self.tracked_point = None
        self.track_token = None
        self.token = None
        self._targets = []
        self._features = []

        # Debug settings
        self.debug_mode = False
        self.save_masks = False
        self.frame_count = 0
        self.no_prompt_warning_counter = 0  # For throttling "no prompts" messages
     
    def init_video_reader(self, input_video_path: str):
        """Initializes the video capture object."""
        self.cap = cv2.VideoCapture(input_video_path)
        if not self.cap.isOpened():
            raise IOError(f"❌ Cannot open video file: {input_video_path}")
        print(f"✅ Video file loaded: {input_video_path}")

    def init_video_writer(self, output_video_path: str, fps: float, frame_size: Tuple[int, int]):
        """Initializes the video writer object."""
        fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for .mp4 files
        self.video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, frame_size)
        if not self.video_writer.isOpened():
            raise IOError(f"❌ Cannot create output video file: {output_video_path}")
        print(f"✅ Video writer initialized for: {output_video_path}")

    def preprocess_image(self, image: np.ndarray) -> np.ndarray:
        """Preprocess image for NanoSAM encoder"""
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        input_tensor = self.transform(image_rgb)
        input_batch = input_tensor.unsqueeze(0).numpy()
        return input_batch
    
    def encode_image(self, image: np.ndarray) -> np.ndarray:
        """Run image through encoder"""
        preprocessed = self.preprocess_image(image)
        encoder_outputs = self.encoder_session.run(
            [self.encoder_output_name],
            {self.encoder_input_name: preprocessed}
        )
        return encoder_outputs[0]
    
    def create_everything_prompts(self, frame_shape: Tuple[int, int]) -> Tuple[np.ndarray, np.ndarray]:
        """Create grid of points for everything mode"""
        h, w = frame_shape[:2]
        model_h, model_w = self.input_size
        self.grid_size = 5
        
        # Create grid of points
        x_points = np.linspace(start=0, stop=model_w-1, num=self.grid_size, dtype=int)
        y_points = np.linspace(start=0, stop=model_h-1, num=7, dtype=int)
        
        # Calculate y-coordinates for the upper 1/5th
        # upper_nth_height = model_h // 8
        upper_nth_height = len(y_points) // 3
    
        y_points = y_points[1:int(upper_nth_height)]
        # y_points = np.linspace(start=0, stop=upper_nth_height - 1, num=self.grid_size, dtype=int)
        
        print('points for everything mode... x: ', len(x_points), ', y: ', len(y_points))

        # append points in a grid
        points = []
        for y in y_points:
            for x in x_points:
                points.append([x, y])
        
        point_coords = np.array([points], dtype=np.float32)
        point_labels = np.ones((1, len(points)), dtype=np.float32)  # All positive
        
        return point_coords, point_labels
    
    def search_for_next_object(self, frame_shape: Tuple[int, int]):

        # Set searching point
        h, w = frame_shape[:2]
        model_h, model_w = self.input_size
        
        px = w // 2
        py = h // 8

        # Use the stored current frame instead of param
        if hasattr(self, 'current_frame') and self.current_frame is not None:
            image_rgb = cv2.cvtColor(self.current_frame, cv2.COLOR_BGR2RGB)
            image_pil = PIL.Image.fromarray(image_rgb)
    
        # Re-initialize tracking
        try:
            logger.info(f"Using ({px}, {py}) to initialize tracking...")
            self.tracked_mask = self.tracker.init(image_pil, point=(px, py))
            self.tracked_point = (px, py)   # doesnt return centroid like .update() because the chosen point is the intial "centroid"
            self.tracking_active = True
            logger.info(f"🏁 Tracking init complete...")
        except Exception as e:
            self.tracking_active = False
            logger.warning(f"❌ Failed to initialize tracking: {e}")
        return 
    
    def set_point_prompt(self, frame_shape: Tuple[int, int]) -> Tuple[Optional[np.ndarray], Optional[np.ndarray]]:
        """
        Create point prompts from a set headig point
        Corresponds to setting self.current_mode = PromptMode.HEADING
        """
        h, w = frame_shape[:2]
        model_h, model_w = self.input_size
        
        px = w // 2
        py = h // 8

        self.fixed_points.append((px, py))

        points = []
        labels = []
        
        # Add scaled hardcoded points
        model_x = int(px * model_w / w)
        model_y = int(py * model_h / h)
        points.append([model_x, model_y])
        labels.append(1)
        
        if not points:
            return None, None
        
        point_coords = np.array([points], dtype=np.float32)
        point_labels = np.array([labels], dtype=np.float32)
        
        return point_coords, point_labels
    
    def create_point_prompts(self, frame_shape: Tuple[int, int]) -> Tuple[Optional[np.ndarray], Optional[np.ndarray]]:
        """Create point prompts from clicked points"""
        if not self.positive_points and not self.negative_points:
            return None, None
        
        h, w = frame_shape[:2]
        model_h, model_w = self.input_size
        
        points = []
        labels = []
        
        # Add positive points
        for px, py in self.positive_points:
            model_x = int(px * model_w / w)
            model_y = int(py * model_h / h)
            points.append([model_x, model_y])
            labels.append(1)
        
        # Add negative points
        for nx, ny in self.negative_points:
            model_x = int(nx * model_w / w)
            model_y = int(ny * model_h / h)
            points.append([model_x, model_y])
            labels.append(0)
        
        if not points:
            return None, None
        
        point_coords = np.array([points], dtype=np.float32)
        point_labels = np.array([labels], dtype=np.float32)
        
        return point_coords, point_labels
    
    def create_bbox_prompts(self, frame_shape: Tuple[int, int]) -> Tuple[Optional[np.ndarray], Optional[np.ndarray]]:
        """Create bounding box prompts"""
        if self.bbox_start is None or self.bbox_end is None:
            return None, None
        
        h, w = frame_shape[:2]
        model_h, model_w = self.input_size
        
        # Convert bbox to model coordinates
        x1 = min(self.bbox_start[0], self.bbox_end[0]) * model_w / w
        y1 = min(self.bbox_start[1], self.bbox_end[1]) * model_h / h
        x2 = max(self.bbox_start[0], self.bbox_end[0]) * model_w / w
        y2 = max(self.bbox_start[1], self.bbox_end[1]) * model_h / h
        
        # Convert bbox to corner points
        points = [
            [x1, y1],  # Top-left
            [x2, y2],  # Bottom-right
        ]
        
        point_coords = np.array([points], dtype=np.float32)
        point_labels = np.array([[2, 3]], dtype=np.float32)  # 2,3 for bbox corners
        
        return point_coords, point_labels

    def decode_masks(self, 
                    image_embeddings: np.ndarray,
                    point_coords: Optional[np.ndarray] = None,
                    point_labels: Optional[np.ndarray] = None,
                    show_best = False) -> List[np.ndarray]:
        """
        Decode masks from embeddings and prompts, filtering by score and surface area.
        Args:
            image_embeddings (np.ndarray): The image embeddings from the encoder. Shape: [batch_size, 256, 64, 64]
            point_coords (np.ndarray): Coordinates of point prompts. Shape: [batch_size, num_points, 2]
            point_labels (np.ndarray): Labels for point prompts. Shape: [batch_size, num_points]
            show_best (bool): If True, returns only the single highest-scoring mask.

        Return:
            all_detected_masks (List[np.ndarray]): List of masks that passed all filters.
                                                Each mask is a 2D np.ndarray.
        """
        
        if point_coords is None or point_labels is None:
            self.no_prompt_warning_counter += 1
            if self.no_prompt_warning_counter % 30 == 1:
                print("🔍 No prompts available")
            return []
        
        print(f"🔍 Decoding masks:")
        print(f"   Image embeddings shape: {image_embeddings.shape} [batch, channel, h, w]")
        print(f"   Point coords shape: {point_coords.shape} [batch, num_prompts, coords(x,y)]")
        print(f"   Point coords: {point_coords}")
        print(f"   Point labels shape: {point_labels.shape} [batch, num_prompts]")
        print(f"   Point labels: {point_labels}")
        
        # Prepare decoder inputs
        decoder_inputs = {
            'image_embeddings': image_embeddings,
            'point_coords': point_coords,
            'point_labels': point_labels,
        }
        
        # Add optional inputs with defaults
        if 'mask_input' in self.decoder_input_names:
            # Dummy mask input. Shape: [batch, 1, h, w]
            mask_input = np.zeros((1, 1, 256, 256), dtype=np.float32) 
            decoder_inputs['mask_input'] = mask_input
            print(f"   Added mask_input: {mask_input.shape}")
            
        if 'has_mask_input' in self.decoder_input_names:
            # Dummy flag to indicate no prior mask input. Shape: [1]
            decoder_inputs['has_mask_input'] = np.array([0], dtype=np.float32) 
            print(f"   Added has_mask_input: [0]")
        
        print(f"   Decoder input names: {list(decoder_inputs.keys())}")
        
        try:
            # Run the decoder to get all outputs.
            start_time = time.time()
            all_outputs = self.decoder_session.run(None, decoder_inputs)
            decode_time = time.time() - start_time
            print(f"✅ Decoder successful in {decode_time*1000:.2f}ms")

            # Assume the outputs are in the order [scores, masks].
            scores_out, masks_out = all_outputs
            
            # Print info about outputs for debugging.
            # Scores shape: [batch, num_masks]
            print(f"   Output 0 scores_out (iou_predictions): shape {scores_out.shape}, range [{scores_out.min():.3f}, {scores_out.max():.3f}]") 
            # Masks shape: [batch, num_masks, h, w]
            print(f"   Output 1 masks_out (low_res_masks): shape {masks_out.shape}, range [{masks_out.min():.3f}, {masks_out.max():.3f}]") 

            # Set filtering thresholds.
            confidence_threshold = 0.7
            area_min_ratio = 0.0005         # Filter out masks smaller than 0.05% of the image 
            area_max_ratio = 0.09           # Filter out masks larger than 50% of the image 

            # Get raw masks and scores, ensuring they are correctly shaped for iteration. 
            # Flattens to a 1D array of shape [num_masks] 
            scores = scores_out.flatten() 
            # Removes the batch dimension, leaving [num_masks, h, w] 
            masks_tensor = masks_out[0]
            print('unpacked masks and scores...')

            all_detected_masks = []
            
            # Determine original image dimensions for surface area calculation 
            # h_orig, w_orig = self.frame_shape[:2]
            h_orig, w_orig = self.frame_height, self.frame_width
            total_pixels = self.frame_height * self.frame_width

            # Get the index of the highest-scoring mask
            if show_best:
                print('shaowing best mask...')
                best_mask_idx = np.argmax(scores) 
                best_score = scores[best_mask_idx]
                best_mask = masks_tensor[best_mask_idx]
                print(f"   Selected best mask (index {best_mask_idx}) with score {best_score:.3f}")
                
                # Resize mask to original image size for surface area calculation
                best_mask_resized = cv2.resize(best_mask, (w_orig, h_orig))
                
                # Binarize mask for accurate area calculation (values above 0 are considered part of the object)
                binary_mask = (best_mask_resized > 0).astype(np.uint8) 
                area = np.sum(binary_mask)
                area_ratio = area / total_pixels
                print(f"   Best mask area ratio: {area_ratio:.4f}")
                
                # Check if best mask passes score and area filters
                if best_score >= confidence_threshold and area_min_ratio < area_ratio < area_max_ratio:
                    all_detected_masks.append(best_mask_resized)
                    print("   ✅ Best mask passed all filters.")
                else:
                    print("   ❌ Best mask failed one or more filters.")

            # Iterate through all masks and their corresponding scores.
            else:
                for i in range(len(scores)):
                    score = scores[i]
                    mask = masks_tensor[i]
                    
                    # Resize mask to original image size for area calculation
                    mask_resized = cv2.resize(mask, (w_orig, h_orig))
                    
                    # Binarize mask for accurate area calculation
                    binary_mask = (mask_resized > 0).astype(np.uint8)
                    area = np.sum(binary_mask)
                    area_ratio = area / total_pixels

                    # Filter masks based on both confidence and surface area
                    if score >= confidence_threshold and area_min_ratio < area_ratio < area_max_ratio:
                        print(f"   ✅ Accepted mask {i} with score {score:.3f} and area ratio {area_ratio:.4f}")
                        all_detected_masks.append(mask_resized)
                    else:
                        print(f"   ❌ Rejected mask {i} (score: {score:.3f}, area ratio: {area_ratio:.4f})")
            
            # Edge case: no masks found.
            if not all_detected_masks:
                print("   ⚠️ No masks passed the filters. Returning empty list.")
            
            return all_detected_masks
        except Exception as e:
            print(f"❌ Decoder failed: {e}")
            return np.zeros((1, 1, self.input_size[0], self.input_size[1]), dtype=np.float32)
    
    def update_fps(self):
        """Update FPS counter"""
        self.fps_counter += 1
        current_time = time.time()
        elapsed = current_time - self.fps_start_time
        
        if elapsed >= 1.0:
            self.current_fps = self.fps_counter / elapsed
            self.fps_counter = 0
            self.fps_start_time = current_time  
    
    # ----- Overlaying and drawing utils -------- #

    def overlay_masks(self, image: np.ndarray, masks: List[np.ndarray], alpha: float = 0.5) -> np.ndarray:
        """Overlay multiple segmentation masks on image"""
        result = image.copy()
        
        logger.info(f"🎨 Overlaying masks:")
        logger.info(f"   Input image shape: {image.shape}")
        logger.info(f"   Input is a list of {len(masks)} masks.") # Correct way to check the input
        
        if len(masks.shape) == 4:
            masks = masks[0]  # Remove batch dimension
            logger.info(f"   Masks after batch removal: {masks.shape}")
        
        h, w = image.shape[:2]
        
        # Colors for different masks
        colors = [
            [0, 255, 0],    # Green
            [255, 0, 0],    # Blue  
            [0, 0, 255],    # Red
            [255, 255, 0],  # Cyan
            [255, 0, 255],  # Magenta
            [0, 255, 255],  # Yellow
        ]
        
        mask_applied = False
        
        # Handle single mask case
        if len(masks.shape) == 2:
            masks = [masks]
        
        for i, mask in enumerate(masks):
            logger.info(f"   Processing mask {i}: shape {mask.shape}, range [{mask.min():.3f}, {mask.max():.3f}]")
            
            if mask.shape != (h, w):
                mask_resized = cv2.resize(mask, (w, h))
                logger.info(f"   Resized mask to: {mask_resized.shape}")
            else:
                mask_resized = mask
            
            # Try different thresholds to see what works
            # For SAM models, masks can have different value ranges
            thresholds = [0.0, 0.1, 0.3, 0.5]
            
            # Also try adaptive threshold based on mask statistics
            if mask_resized.max() > mask_resized.min():
                adaptive_thresh = mask_resized.mean() + 0.5 * mask_resized.std()
                thresholds.append(adaptive_thresh)
                logger.info(f"   Added adaptive threshold: {adaptive_thresh:.3f}")
            
            for threshold in thresholds:
                mask_binary = (mask_resized > threshold).astype(np.uint8)
                pixel_count = np.sum(mask_binary)
                logger.info(f"   Threshold {threshold:.3f}: {pixel_count} pixels ({pixel_count/(h*w)*100:.1f}%)")
                
                # Accept mask if it has reasonable coverage (0.1% to 50% of image)
                coverage_percent = pixel_count/(h*w)*100
                if 0.1 <= coverage_percent <= 50.0 and not mask_applied:
                    # Create colored overlay
                    color = colors[i % len(colors)]
                    overlay = result.copy()
                    overlay[mask_binary == 1] = color
                    
                    # Blend with result
                    result = cv2.addWeighted(result, 1 - alpha, overlay, alpha, 0)
                    mask_applied = True
                    logger.info(f"   ✅ Applied mask {i} with threshold {threshold:.3f}, color {color}")
                    break
        
        if not mask_applied:
            logger.info("   ⚠️  No masks were applied (all below threshold)")
        
        return result
    
    def overlay_bboxes(self, image: np.ndarray, masks: List[np.ndarray]) -> np.ndarray:
        """Overlay bounding boxes on segmented regions."""
        result = image.copy()
        
        logger.info(f"📦 Overlaying bounding boxes:")
        logger.info(f"   Input is a list of {len(masks)} masks.") # Correct way to check the input
        
        h, w = image.shape[:2]

        colors = [
            (0, 255, 0),    # Green
            (255, 0, 0),    # Blue  
            (0, 0, 255),    # Red
            (255, 255, 0),  # Cyan
            (255, 0, 255),  # Magenta
            (0, 255, 255),  # Yellow
        ]
        
        bbox_drawn = False
        
        # This loop correctly iterates over the list of masks
        for i, mask in enumerate(masks):
            # Check for empty masks before processing
            if mask.size == 0:
                logger.info(f"   Skipping mask {i} as it is empty.")
                continue

            # Assuming the masks in the list are 2D arrays (H, W)
            if mask.shape != (h, w):
                mask_resized = cv2.resize(mask, (w, h), interpolation=cv2.INTER_LINEAR)
            else:
                mask_resized = mask
            
            mask_binary = (mask_resized > 0).astype(np.uint8) * 255 
            
            contours, _ = cv2.findContours(mask_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            if not contours:
                logger.info(f"   No contours found for mask {i}.")
                continue

            largest_contour = max(contours, key=cv2.contourArea)
            
            x, y, w_bbox, h_bbox = cv2.boundingRect(largest_contour)
            
            color = colors[i % len(colors)]
            cv2.rectangle(result, (x, y), (x + w_bbox, y + h_bbox), color, 2)
            bbox_drawn = True
            logger.info(f"   ✅ Drawn bbox for mask {i} with color {color}")

        if not bbox_drawn:
            logger.info("   ⚠️  No bounding boxes were drawn.")
        
        return result

    def draw_prompts(self, image: np.ndarray) -> np.ndarray:
        """Draw current prompts on image"""
        result = image.copy()

        # if self.show_bbox:
        #     # early exit
        #     return

        if self.current_mode == PromptMode.HEADING:
            px, py = self.fixed_points[0]
            cv2.circle(result, (px, py), 5, (0, 255, 0), -1)
            cv2.circle(result, (px, py), 7, (255, 255, 255), 2)

        # Draw positive points (green circles)
        for px, py in self.positive_points:
            cv2.circle(result, (px, py), 5, (0, 255, 0), -1)
            cv2.circle(result, (px, py), 7, (255, 255, 255), 2)
        
        # Draw negative points (red circles)
        for nx, ny in self.negative_points:
            cv2.circle(result, (nx, ny), 5, (0, 0, 255), -1)
            cv2.circle(result, (nx, ny), 7, (255, 255, 255), 2)
        
        # Draw bounding box
        if self.bbox_start and self.bbox_end:
            cv2.rectangle(result, self.bbox_start, self.bbox_end, (255, 0, 255), 2)
        elif self.bbox_start and self.drawing_bbox and self.bbox_end:
            cv2.rectangle(result, self.bbox_start, self.bbox_end, (128, 0, 128), 2)
        
        return result
    
    def draw_tracking(self, image: np.ndarray) -> np.ndarray:
        """Draw tracking results compatible with OnnxTracker"""
        result = image.copy()
        
        # Draw tracked mask
        if self.tracked_mask is not None and self.tracking_active:
            try:
                logger.debug(f"[draw_tracking] Drawing tracked mask: type={type(self.tracked_mask)}")
                
                # Handle different mask formats
                if isinstance(self.tracked_mask, torch.Tensor):
                    mask_np = self.tracked_mask.detach().cpu().numpy()
                else:
                    mask_np = self.tracked_mask
                
                logger.debug(f"[draw_tracking] Mask shape: {mask_np.shape}")
                
                # Remove batch/channel dimensions if present
                if len(mask_np.shape) == 4:
                    mask_np = mask_np[0, 0]
                elif len(mask_np.shape) == 3:
                    mask_np = mask_np[0]
                elif len(mask_np.shape) == 2:
                    pass  # Already 2D
                else:
                    logger.debug(f"[draw_tracking] Unexpected mask shape: {mask_np.shape}")
                    return result
                
                h, w = image.shape[:2]
                
                # Resize mask to match frame
                if mask_np.shape != (h, w):
                    mask_resized = cv2.resize(mask_np, (w, h), interpolation=cv2.INTER_LINEAR)
                else:
                    mask_resized = mask_np
                
                logger.debug(f"[draw_tracking] Mask range: [{mask_resized.min():.3f}, {mask_resized.max():.3f}]")
                
                # Create binary mask with proper threshold
                # Use 0.0 as threshold since SAM outputs are typically > 0 for foreground
                binary_mask = (mask_resized > 0.0).astype(np.uint8)
                
                # Count pixels for debugging
                pixel_count = np.sum(binary_mask)
                coverage = pixel_count / (h * w) * 100
                logger.info(f"[draw_tracking] Binary mask: {pixel_count} pixels ({coverage:.1f}% coverage)")
                
                if pixel_count > 0:  # Only draw if mask has content
                    # Create colored overlay (green for tracking)
                    overlay = result.copy()
                    overlay[binary_mask == 1] = [0, 255, 0]  # Green in BGR
                    
                    # Blend with result
                    alpha = 0.3  # Make it semi-transparent
                    result = cv2.addWeighted(result, 1 - alpha, overlay, alpha, 0)
                    logger.info(f"[draw_tracking] 🎨 Applied green mask overlay")
                else:
                    logger.info(f"[draw_tracking] No pixels to draw in mask")
                    
            except Exception as e:
                logger.warning(f"Failed to draw tracking mask: {e}")
                import traceback
                traceback.print_exc()
        
        # Draw tracked point (similar to draw_prompts)
        if self.tracked_point is not None and self.tracking_active:
            x, y = self.tracked_point
            x, y = int(x), int(y)  # Guard against floats
            # Draw filled circle with white outline (consistent with prompts)
            cv2.circle(result, (x, y), 5, (0, 255, 0), -1)  # Green filled
            cv2.circle(result, (x, y), 7, (255, 255, 255), 2)  # White outline
            logger.info(f"[draw_tracking] 🎨 Drew tracking point at ({x}, {y})")
        
        return result

    def return_bbox_xywh(self, image: np.ndarray, masks: List[np.ndarray]) -> np.ndarray:
        """Publish bounding boxes (xywh) of segmented mask regions."""
        result = image.copy()
        
        print(f"📦 Overlaying bounding boxes:")
        print(f"   Input is a list of {len(masks)} masks.") # Correct way to check the input
        
        h, w = image.shape[:2]

        colors = [
            (0, 255, 0),    # Green
            (255, 0, 0),    # Blue  
            (0, 0, 255),    # Red
            (255, 255, 0),  # Cyan
            (255, 0, 255),  # Magenta
            (0, 255, 255),  # Yellow
        ]
        
        bbox_drawn = False
        
        # This loop correctly iterates over the list of masks
        for i, mask in enumerate(masks):
            # Check for empty masks before processing
            if mask.size == 0:
                print(f"   Skipping mask {i} as it is empty.")
                continue

            # Assuming the masks in the list are 2D arrays (H, W)
            if mask.shape != (h, w):
                mask_resized = cv2.resize(mask, (w, h), interpolation=cv2.INTER_LINEAR)
            else:
                mask_resized = mask
            
            mask_binary = (mask_resized > 0).astype(np.uint8) * 255 
            
            contours, _ = cv2.findContours(mask_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            if not contours:
                print(f"   No contours found for mask {i}.")
                continue

            largest_contour = max(contours, key=cv2.contourArea)
            
            x, y, w_bbox, h_bbox = cv2.boundingRect(largest_contour)
            
            color = colors[i % len(colors)]
            cv2.rectangle(result, (x, y), (x + w_bbox, y + h_bbox), color, 2)
            bbox_drawn = True
            print(f"   ✅ Drawn bbox for mask {i} with color {color}")

        if not bbox_drawn:
            print("   ⚠️  No bounding boxes were drawn.")
        
        return result
    
    def clear_prompts(self):
        """Clear all prompts"""
        self.positive_points = []
        self.negative_points = []
        self.tracked_point = None
        self.bbox_start = None
        self.bbox_end = None
        self.drawing_bbox = False
        self.everything_mode_active = False
        print("Cleared all prompts")
    
    def run_video_processing(self, input_video_path: str, output_video_path: str):
        """
        Processes video frame by frame and saves output.
        """

        print(f"Starting video segmentation on: {input_video_path}")

        self.init_video_reader(input_video_path)
        
        # Get video properties for writer
        fps = self.cap.get(cv2.CAP_PROP_FPS)
        width = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        frame_size = (width, height)
        vertical_displacement = height - (height // 4)
        print(f"    new object search threshold is: {vertical_displacement}px")
        
        self.init_video_writer(output_video_path, fps, frame_size)
        
        image_embeddings = None
        last_embedding_time = 0
        embedding_interval = 0.5

        try:
            while self.cap.isOpened():
                ret, frame = self.cap.read()
                if not ret:
                    break
                
                self.frame_count += 1
                current_time = time.time()

                # Set the frame as parameter for mouse callback (for double-click tracking)
                self.current_frame = frame

                # PART 1: Handle tracking updates (if tracking is in process)
                if self.tracking_active and self.tracker.token is not None:
                    try:
                        logger.info("New frame: updating tracking")
                        # Convert frame to PIL for tracker
                        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                        image_pil = PIL.Image.fromarray(image_rgb)
                        
                        # Update tracking
                        mask_result, point_result = self.tracker.update(image_pil)
                        if mask_result is not None and point_result is not None:
                            self.tracked_mask = mask_result
                            self.tracked_point = point_result
                            self.tracking_text = "Existing tracking updated !!"
                            logger.info(f"✅  Tracking updated, new point: {self.tracked_point}")
                        else:
                            logger.info("😵‍💫 Tracking update failed, no results returned/object lost...")
                            self.tracking_active = False
                    except Exception as e:
                        logger.warning(f"🚨 Tracking update failed, [exception]: {e}")
                        self.tracking_active = False
                
                # Update image embeddings periodically with NanoSAM Encoder
                if current_time - last_embedding_time > embedding_interval:
                    image_embeddings = self.encode_image(frame)
                    last_embedding_time = current_time
                
                # Copy the frame
                result_frame = frame.copy()     # copy initial frame to draw on later
                
                # Set the frame height and width params
                self.frame_height = result_frame.shape[0]
                self.frame_width = result_frame.shape[1]
                point_coords, point_labels = None, None
            
                # PART 2: Get prompts based on current_mode
                if self.current_mode == PromptMode.EVERYTHING and image_embeddings is not None:
                    point_coords, point_labels = self.create_everything_prompts(frame.shape)
                elif self.current_mode == PromptMode.HEADING:
                    point_coords, point_labels = self.set_point_prompt(frame.shape)
                    print(f'PromptMode set to == HEADING....')
                    print(f'prompt point set to {point_coords}')
                elif self.current_mode == PromptMode.POINT:
                    point_coords, point_labels = self.create_point_prompts(frame.shape)
                elif self.current_mode == PromptMode.BBOX:
                    point_coords, point_labels = self.create_bbox_prompts(frame.shape)
                elif self.current_mode == PromptMode.TRACKING_ALGO:
                    # In TRACKING_ALGO mode, if the tracker is idle generate a new prompt for static segmentation
                    if self.tracking_active == False:
                        # reset the mask and centroid values 
                        self.tracked_mask = None
                        self.tracked_point = None
                        logger.info(" 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg")
                        self.search_for_next_object(frame.shape)  # search for an object to prompt
                        self.tracking_text = "Init new track"
                    elif self.tracking_active == True:
                        logger.debug("TRACKING_ALGO mode - skipping new object search...")

                # PART 3b: Draw prompts and tracking
                # result_frame = self.draw_prompts(result_frame)
                result_frame = self.draw_tracking(result_frame)

                # PART 4: Fetch from the top of the frame
                # This is where the algo decides to break from the current tracked object 
                # and fetch the next top most object
                # note the origin (0,0) is the top left corner
                if self.tracked_point is not None:  # Add this check
                    vertical_displacement = frame.shape[0] - (frame.shape[0] // 4)
                    height_thresh = int(vertical_displacement)
                    if self.tracked_point[1] > height_thresh:
                        logger.info("🏁 TRACKING_ALGO mode - current object out of view, search for new object next frame...")
                        self.tracking_active = False    # this triggers searhing in the next iter
                        self.tracking_text = "Out of sight"

                else:
                    logger.debug("No tracked point available for boundary check")
                
                # PART 5: Text Status (top right corner) ------------- #
                
                mode_text = f"Mode: {self.current_mode.value.upper()}"
                cv2.putText(result_frame, mode_text, (10, 30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
                
                tracking_text = f'Active Tracking: {self.tracking_active}'
                cv2.putText(result_frame, tracking_text, (10, 60), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
                
                inference_text = f'Search State: {self.tracking_text}'
                cv2.putText(result_frame, inference_text, (10, 90), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
                    
                # Print tag for tracking all processed frames
                self.video_writer.write(result_frame)    # <--- Write the result frame to the output video
                logger.info(f"Processed frame {self.frame_count}/{int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))}")

        except Exception as e:
            print(f"❌ An error occurred during processing: {e}")
        finally:
            print(f"Finished task...")
            self.cleanup()
            

    def cleanup(self):
        """Clean up resources"""
        if self.cap:
            self.cap.release()
        if self.video_writer:
            self.video_writer.release()
        cv2.destroyAllWindows()

# %%
# EXECUTION: NEW NOTEBOOK CELL

def main():
    """Main function to run the video segmentation script."""
    segmenter = NanoSAMEnhanced(
        encoder_path=ENCODER_MODEL,
        decoder_path=DECODER_MODEL,
    )
    
    # Configure the instance based on notebook variables
    segmenter.grid_size = GRID_SIZE
    segmenter.show_bbox = SHOW_BBOX_OVERLAY
    segmenter.current_mode = PROMPT_MODE
    
    # Run the processing
    segmenter.run_video_processing(INPUT_VIDEO, OUTPUT_VIDEO)

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Loading encoder model...
# INFO:__main__:Loading decoder model...
# 2025-09-03 16:31:33.731105093 [W:onnxruntime:Default, onnxruntime_pybind_state.cc:503 RegisterTensorRTPluginsAsCustomOps] The custom op domain name trt.plugins is already in session option.
# INFO:__main__:Using enc_sess providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# INFO:__main__:Using dec_sess providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# INFO:__main__:Decoder inputs: ['image_embeddings', 'point_coords', 'point_labels', 'mask_input', 'has_mask_input']
# INFO:__main__:Decoder outputs: ['iou_predictions', 'low_res_masks']
# INFO:__main__:Multiple decoder outputs detected: ['iou_predictions', 'low_res_masks']
# INFO:__main__:Using mask output: low_res_masks
# INFO:nanosam.utils.tracker:Initializing ONNXTracker...
# INFO:nanosam.utils.tracker:ONNXTracker initialization complete
# INFO:__main__:✅ Tracker initialized with ONNX models
# [predictor.py] Using provided ONNX sessions
# Starting video segmentation on: /home/copter/Data/SimulatedDroneAngledCity - Trimmed 2.mp4
# ✅ Video file loaded: /home/copter/Data/SimulatedDroneAngledCity - Trimmed 2.mp4
#     new object search threshold is: 810px
# ✅ Video writer initialized for: /home/copter/Data/sim_tracker_algo_output_3.mp4
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 40434 pixels (1.9% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 40434 pixels (1.9% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 1/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.019, -0.586]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.016, -0.593]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 41969 pixels (2.0% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 41969 pixels (2.0% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.019, -0.660]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.015, -0.668]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 50177 pixels (2.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 50177 pixels (2.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 3/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.977, -0.605]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.974, -0.615]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 38739 pixels (1.9% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 38739 pixels (1.9% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 4/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.073, -0.829]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.069, -0.837]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 41492 pixels (2.0% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 41492 pixels (2.0% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 5/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.261, -0.760]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.257, -0.772]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 46683 pixels (2.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 46683 pixels (2.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 6/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.145, -0.808]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.142, -0.816]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 36836 pixels (1.8% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 36836 pixels (1.8% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 7/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.056, -0.846]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.055, -0.863]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 33086 pixels (1.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 33086 pixels (1.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 8/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.034, -0.887]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.031, -0.905]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 25625 pixels (1.2% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 25625 pixels (1.2% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 9/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.574, -0.935]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.571, -0.955]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 30769 pixels (1.5% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 30769 pixels (1.5% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 10/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.472, -0.782]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.468, -0.801]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 32027 pixels (1.5% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 32027 pixels (1.5% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 11/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.377, -1.213]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.374, -1.214]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 27952 pixels (1.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 27952 pixels (1.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 12/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-11.334, -0.859]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-11.329, -0.860]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 39469 pixels (1.9% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 39469 pixels (1.9% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 13/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.886, -0.920]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.880, -0.922]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 36360 pixels (1.8% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 36360 pixels (1.8% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 14/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.889, -0.970]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.884, -0.973]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 33552 pixels (1.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 33552 pixels (1.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 15/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.945, -1.037]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.942, -1.039]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 44559 pixels (2.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 44559 pixels (2.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 16/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.430, -0.784]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.429, -0.788]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 45345 pixels (2.2% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 45345 pixels (2.2% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 17/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.403, -0.837]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.401, -0.841]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 42444 pixels (2.0% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 42444 pixels (2.0% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 18/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.609, -0.789]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.605, -0.793]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 32438 pixels (1.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 32438 pixels (1.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 19/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.895, -0.909]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.891, -0.917]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 33417 pixels (1.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 33417 pixels (1.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 20/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.463, -0.791]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.460, -0.800]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 32988 pixels (1.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 32988 pixels (1.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 21/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.505, -0.778]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.502, -0.788]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 30971 pixels (1.5% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 30971 pixels (1.5% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 22/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.866, -0.744]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.861, -0.754]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 31647 pixels (1.5% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 31647 pixels (1.5% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 23/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.690, -0.783]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.684, -0.798]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 28060 pixels (1.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 28060 pixels (1.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 24/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.873, -0.723]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.869, -0.748]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 46895 pixels (2.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 46895 pixels (2.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 25/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.268, -0.236]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.265, -0.259]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 48889 pixels (2.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 48889 pixels (2.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 26/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.233, -0.151]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.231, -0.178]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 53117 pixels (2.6% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 53117 pixels (2.6% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 27/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.210, -0.151]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.207, -0.180]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 55786 pixels (2.7% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 55786 pixels (2.7% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 28/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.232, 0.003]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 1
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.230, -0.003]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 61786 pixels (3.0% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 61786 pixels (3.0% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 29/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.013, 0.046]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.010, 0.026]
# INFO:nanosam.utils.tracker:Predicted mask has 31 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (885, 55)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.012, Size ratio: 0.037, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: Valid, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 1)
# INFO:__main__:✅  Tracking updated, new point: (885, 55)
# INFO:__main__:[draw_tracking] Binary mask: 2296 pixels (0.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (885, 55)
# INFO:__main__:Processed frame 30/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.001, 0.092]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 8
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-9.999, 0.070]
# INFO:nanosam.utils.tracker:Predicted mask has 106 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (884, 52)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.075, Size ratio: 0.037, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: Valid, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 2)
# INFO:__main__:✅  Tracking updated, new point: (884, 52)
# INFO:__main__:[draw_tracking] Binary mask: 2271 pixels (0.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (884, 52)
# INFO:__main__:Processed frame 31/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-9.972, 0.176]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 4
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-9.969, 0.156]
# INFO:nanosam.utils.tracker:Predicted mask has 95 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (1127, 74)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.051, Size ratio: 0.059, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: IoU degraded significantly, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 3)
# INFO:__main__:✅  Tracking updated, new point: (1127, 74)
# INFO:__main__:[draw_tracking] Binary mask: 3626 pixels (0.2% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (1127, 74)
# INFO:__main__:Processed frame 32/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.037, 0.063]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.032, 0.045]
# INFO:nanosam.utils.tracker:Predicted mask has 19 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (1127, 73)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.025, Size ratio: 0.057, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: IoU degraded significantly, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 63529 pixels (3.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 63529 pixels (3.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 33/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.397, -0.071]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.395, -0.076]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 70678 pixels (3.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 70678 pixels (3.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 34/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.382, -0.003]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.379, -0.004]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 75792 pixels (3.7% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 75792 pixels (3.7% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 35/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-10.109, -0.019]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 0
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-10.105, -0.023]
# INFO:nanosam.utils.tracker:Predicted mask has 0 nonzero pixels
# WARNING:nanosam.utils.tracker:❌ apply_token() prediction yeilded no matches, tracking update lost!
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 85754 pixels (4.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 85754 pixels (4.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 36/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-4.583, 0.887]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2437
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-4.581, 0.883]
# INFO:nanosam.utils.tracker:Predicted mask has 76923 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (800, 66)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.103, Size ratio: 0.178, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: Valid, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 1)
# INFO:__main__:✅  Tracking updated, new point: (800, 66)
# INFO:__main__:[draw_tracking] Binary mask: 15241 pixels (0.7% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (800, 66)
# INFO:__main__:Processed frame 37/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-4.583, 0.888]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2414
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-4.582, 0.887]
# INFO:nanosam.utils.tracker:Predicted mask has 76288 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (796, 67)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.112, Size ratio: 0.172, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.132, Validation: Valid, Trend: improving
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 2)
# INFO:__main__:✅  Tracking updated, new point: (796, 67)
# INFO:__main__:[draw_tracking] Binary mask: 14718 pixels (0.7% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (796, 67)
# INFO:__main__:Processed frame 38/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-4.601, 1.002]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2378
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-4.600, 1.000]
# INFO:nanosam.utils.tracker:Predicted mask has 75379 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (797, 67)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.116, Size ratio: 0.185, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: Valid, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# INFO:nanosam.utils.tracker:Recovery attempted (attempt 3)
# INFO:__main__:✅  Tracking updated, new point: (797, 67)
# INFO:__main__:[draw_tracking] Binary mask: 15834 pixels (0.8% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (797, 67)
# INFO:__main__:Processed frame 39/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-4.608, 1.100]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 2354
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-4.607, 1.098]
# INFO:nanosam.utils.tracker:Predicted mask has 74553 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (738, 73)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.296, Size ratio: 2.242, Movement: 0.0
# INFO:nanosam.utils.tracker:             Confidence: 0.120, Validation: Valid, Trend: stable
# INFO:nanosam.utils.tracker:Reverting to stable token (age: 0)
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 105250 pixels (5.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 105250 pixels (5.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# ...
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 169446 pixels (8.2% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2461/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.593, 6.426]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6214
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.590, 6.413]
# INFO:nanosam.utils.tracker:Predicted mask has 196936 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (793, 118)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.184, Size ratio: 1.029, Movement: 125.1
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.402 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 167932 pixels (8.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 167932 pixels (8.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2462/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.555, 6.350]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6202
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.545, 6.337]
# INFO:nanosam.utils.tracker:Predicted mask has 196278 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (793, 118)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.204, Size ratio: 1.046, Movement: 125.1
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.406 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 166659 pixels (8.0% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 166659 pixels (8.0% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2463/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.451, 6.475]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6222
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.443, 6.462]
# INFO:nanosam.utils.tracker:Predicted mask has 197153 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (794, 119)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.219, Size ratio: 1.061, Movement: 124.4
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.408 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 171994 pixels (8.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 171994 pixels (8.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2464/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.501, 6.095]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6335
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.493, 6.082]
# INFO:nanosam.utils.tracker:Predicted mask has 200335 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (793, 120)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.207, Size ratio: 1.026, Movement: 124.4
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.407 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 171808 pixels (8.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 171808 pixels (8.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2465/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.463, 5.916]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6336
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.455, 5.902]
# INFO:nanosam.utils.tracker:Predicted mask has 200750 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (792, 120)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.206, Size ratio: 1.032, Movement: 124.7
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.409 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 168335 pixels (8.1% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 168335 pixels (8.1% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2466/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.332, 5.997]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6075
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.324, 5.982]
# INFO:nanosam.utils.tracker:Predicted mask has 191911 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (793, 121)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.170, Size ratio: 1.037, Movement: 124.0
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.403 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 172540 pixels (8.3% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 172540 pixels (8.3% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2467/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.119, 5.645]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6231
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.118, 5.634]
# INFO:nanosam.utils.tracker:Predicted mask has 197323 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (793, 122)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.219, Size ratio: 1.030, Movement: 123.6
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.410 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 174799 pixels (8.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 174799 pixels (8.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2468/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-7.858, 5.831]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6061
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-7.851, 5.818]
# INFO:nanosam.utils.tracker:Predicted mask has 191657 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (795, 123)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.208, Size ratio: 1.026, Movement: 122.6
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.414 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 175904 pixels (8.5% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 175904 pixels (8.5% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2469/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-7.775, 5.440]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6120
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-7.768, 5.426]
# INFO:nanosam.utils.tracker:Predicted mask has 193692 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (795, 123)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.216, Size ratio: 1.022, Movement: 122.6
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.415 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 173954 pixels (8.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 173954 pixels (8.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2470/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-7.815, 5.257]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6017
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-7.814, 5.246]
# INFO:nanosam.utils.tracker:Predicted mask has 190389 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (795, 123)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.198, Size ratio: 1.033, Movement: 122.6
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.415 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 169512 pixels (8.2% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 169512 pixels (8.2% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2471/2472
# INFO:__main__:New frame: updating tracking
# INFO:nanosam.utils.tracker:apply_token output - Shape: torch.Size([1, 1, 256, 256]), Range: [-8.149, 5.815]
# INFO:nanosam.utils.tracker:apply_token nonzero pixels (256x256): 6277
# INFO:nanosam.utils.tracker:After upscale - Shape: torch.Size([1080, 1920]), Range: [-8.140, 5.802]
# INFO:nanosam.utils.tracker:Predicted mask has 198680 nonzero pixels
# INFO:nanosam.utils.tracker:Centroid found at: (792, 123)
# INFO:nanosam.utils.tracker:[Mask Stats] IoU: 0.203, Size ratio: 1.067, Movement: 123.6
# INFO:nanosam.utils.tracker:             Confidence: 0.210, Validation: Size ratio 0.417 out of bounds, Trend: stable
# WARNING:nanosam.utils.tracker:Tracking lost - recovery failed
# INFO:__main__:😵‍💫 Tracking update failed, no results returned/object lost...
# INFO:__main__: 🆕 TRACKING_ALGO mode - reset tracking vars & searching for NEW object at heading 0* deg
# INFO:__main__:Using (960, 135) to initialize tracking...
# INFO:nanosam.utils.tracker:Initializing tracking...
# INFO:nanosam.utils.tracker:Stored original object: 174587 pixels (8.4% coverage)
# INFO:nanosam.utils.tracker:🙌 Tracking initialization complete !
# INFO:__main__:🏁 Tracking init complete...
# INFO:__main__:[draw_tracking] Binary mask: 174587 pixels (8.4% coverage)
# INFO:__main__:[draw_tracking] 🎨 Applied green mask overlay
# INFO:__main__:[draw_tracking] 🎨 Drew tracking point at (960, 135)
# INFO:__main__:Processed frame 2472/2472
# Finished task...
